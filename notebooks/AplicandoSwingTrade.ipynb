# %% [markdown]
# ## Imports

# %%
import yfinance as yf
import plotly.graph_objs as go
import numpy as np

# %% [markdown]
# ## Loading Data

# %%
stock = 'TSLA'
start_date = '2020-01-01'
end_date = '2021-01-01'

ticker = yf.Ticker(stock)
df = ticker.history(interval='1d',
                    start=start_date,
                    end=end_date)
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-01-02 00:00:00-05:00  28.299999  28.713333  28.114000  28.684000
# 2020-01-03 00:00:00-05:00  29.366667  30.266666  29.128000  29.534000
# 2020-01-06 00:00:00-05:00  29.364668  30.104000  29.333332  30.102667
# 2020-01-07 00:00:00-05:00  30.760000  31.441999  30.224001  31.270666
# 2020-01-08 00:00:00-05:00  31.580000  33.232666  31.215334  32.809334
#
#                               Volume  Dividends  Stock Splits
# Date
# 2020-01-02 00:00:00-05:00  142981500        0.0           0.0
# 2020-01-03 00:00:00-05:00  266677500        0.0           0.0
# 2020-01-06 00:00:00-05:00  151995000        0.0           0.0
# 2020-01-07 00:00:00-05:00  268231500        0.0           0.0
# 2020-01-08 00:00:00-05:00  467164500        0.0           0.0

# %% [markdown]
# ## Extraindo médias móveis

# %%
df['mv_7d_1.5_std'] = df['Close'].rolling(7).mean() + df['Close'].rolling(7).std() * 1.5
df['mv_50d'] = df['Close'].rolling(50).mean()

# %% [markdown]
# ## Visualizando dados

# %%
def plotCandleStick(df_, name='ticket', lines=[]):
  tracel = {
      'x': df_.index,
      'open': df_.Open,
      'close': df_.Close,
      'high': df_.High,
      'low': df_.Low,
      'type': 'candlestick',
      'name': name,
      'showlegend':False
  }

  data = [tracel]
  layout = go.Layout()

  fig = go.Figure(data=data , layout=layout)

  if len(lines) > 0:
    for c in lines:
      fig.add_trace(
          go.Scatter(x = list(df_.index),
                     y = df_[c],
                     mode = 'lines',
                     name = c))

  return fig

# %%
plotCandleStick(df, name=stock, lines=['mv_7d_1.5_std', 'mv_50d'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="dae258f5-c30b-49be-b51d-09973475079f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dae258f5-c30b-49be-b51d-09973475079f")) {                    Plotly.newPlot(                        "dae258f5-c30b-49be-b51d-09973475079f",                        [{"close":[28.68400001525879,29.534000396728516,30.1026668548584,31.270666122436523,32.80933380126953,32.089332580566406,31.876667022705078,34.990665435791016,35.861331939697266,34.56666564941406,34.232666015625,34.03333282470703,36.47999954223633,37.97066879272461,38.14666748046875,37.654666900634766,37.201332092285156,37.793331146240234,38.732666015625,42.72066879272461,43.371334075927734,52.0,59.137332916259766,48.97999954223633,49.930667877197266,49.871334075927734,51.41866683959961,51.62533187866211,51.15266799926758,53.599998474121094,53.33533477783203,57.22666549682617,61.16133117675781,59.96066665649414,60.06666564941406,55.58599853515625,53.32733154296875,51.91999816894531,45.266666412353516,44.53266525268555,49.574668884277
# %%
df.dropna(subset = ['sinal_operacao'], inplace=True)

# %% [markdown]
# ## Análisando os dados

# %%
def clean_consecutive_duplicates(df_, subset=None, keep='first', inplace=False):
  if keep == 'first':
    n=1
  else:
    n=-1

  if subset is None:
    filter_ = (df_.shift(n) != df_).any(axis=1)
  else:
    filter_ = (df_[subset].shift(n) != df_[subset]).any(axis=1)

  if inplace:
    df_.drop( index=df_[-filter_].index, inplace=True)
  else:
    return df_.loc[filter_]

# %%
clean_consecutive_duplicates(df, keep='first', subset=['sinal_operacao'], inplace=True)

# %% [markdown]
# ## Verificando a rentabilidade

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#                        Date        Open        High         Low       Close  \
# 0 2020-01-13 00:00:00-05:00   32.900002   35.042000   32.799999   34.990665
# 1 2020-03-13 00:00:00-04:00   39.666668   40.504665   33.466667   36.441334
# 2 2020-04-13 00:00:00-04:00   39.344002   43.466667   38.702000   43.396667
# 3 2020-10-28 00:00:00-04:00  138.826660  139.533340  135.333328  135.339996
# 4 2020-11-05 00:00:00-05:00  142.766663  146.666672  141.333328  146.029999
#
#       Volume  Dividends  Stock Splits  mv_7d_1.5_std      mv_50d  \
# 0  397764000        0.0           0.0      34.520445         NaN
# 1  339604500        0.0           0.0      48.808023   43.886280
# 2  337131000        0.0           0.0      42.345705   43.137080
# 3   76354200        0.0           0.0     143.395267  140.640666
# 4   85243500        0.0           0.0     145.816494  141.028266
#
#   sinal_operacao
# 0          venda
# 1         compra
# 2          venda
# 3         compra
# 4          venda

# %%
df['rentab'] = df['Close'] / df['Close'].shift() * 100 -100

# %% [markdown]
# ## Simulando operações

# %%
valor_investido = 10000
df['Saldo'] = np.NaN

idx_venda = df[df['sinal_operacao'] == 'venda'].index
idx_compra = df[df['sinal_operacao'] == 'compra'].index

df.loc[idx_venda, 'Saldo'] = (valor_investido * (100 + df['rentab'])) / 100 - valor_investido

# %%
df[['Date','Close','rentab','Saldo','mv_7d_1.5_std','mv_50d']]
# Out:
#                        Date       Close      rentab        Saldo  \
# 0 2020-01-13 00:00:00-05:00   34.990665         NaN          NaN
# 1 2020-03-13 00:00:00-04:00   36.441334    4.145872          NaN
# 2 2020-04-13 00:00:00-04:00   43.396667   19.086386  1908.638623
# 3 2020-10-28 00:00:00-04:00  135.339996  211.867257          NaN
# 4 2020-11-05 00:00:00-05:00  146.029999    7.898628   789.862770
# 5 2020-11-09 00:00:00-05:00  140.419998   -3.841677          NaN
# 6 2020-11-17 00:00:00-05:00  147.203339    4.830751   483.075099
#
#    mv_7d_1.5_std      mv_50d
# 0      34.520445         NaN
# 1      48.808023   43.886280
# 2      42.345705   43.137080
# 3     143.395267  140.640666
# 4     145.816494  141.028266
# 5     147.844372  140.766799
# 6     144.926837  140.241332

# %%
df['Saldo'].sum()
# Out:
# 3181.5764919695375
